# %%
import matplotlib.pyplot as plt
import Project_library as pl
import numpy as np

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = [
    'CMU Serif Roman',  # primary CMU serif face
    'Times New Roman',  # fallback
    'Georgia',
    'serif'
]
plt.rcParams['axes.grid'] = True
# 3. Set the global font size:
plt.rcParams['font.size'] = 14  # change this number to taste

# 4. (Optional) Adjust axes titles and labels separately if you like:
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.labelsize'] = 14

# %%
distances = np.arange(100, 1200, 1) # km
frequency = [2,4] # GHz
giga_loss = []
for f in frequency:
    loss =[]
    for d in distances: 
        loss.append(pl.calculate_path_loss(d, f))
    giga_loss.append(loss)

plt.figure(figsize=(6.27, 3))
for idx, l in enumerate(giga_loss):
    plt.plot(distances, l, label=f'Path Loss {frequency[idx]} GHz')
plt.legend()
plt.xlabel('Distance (km)')
plt.ylabel('Path Loss (dB)')
plt.savefig("Path_loss_vs_distance.pdf")
